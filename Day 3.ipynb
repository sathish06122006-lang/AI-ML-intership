# %%
import numpy as np

print("NumPy imported successfully")
# Out:
# NumPy imported successfully

# %%
arr1 = np.array([10, 20, 30, 40, 50])

print("1D Array:")
print(arr1)
# Out:
# 1D Array:
# [10 20 30 40 50]

# %%
arr2 = np.array([[1, 2, 3],
                 [4, 5, 6]])

print("2D Array:")
print(arr2)
# Out:
# 2D Array:
# [[1 2 3]
#  [4 5 6]]

# %%
print(arr[0])     
print(arr[-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(arr[0])
#       2 print(arr[-1])
#
# NameError: name 'arr' is not defined

# %%
import numpy as np

arr = np.array([10, 20, 30, 40, 50])

print(arr)
# Out:
# [10 20 30 40 50]

# %%
print(arr[0])     
print(arr[-1])
# Out:
# 10
# 50

# %%
print(arr[1:4])
# Out:
# [20 30 40]

# %%
a = np.array([10,20,30])
b = np.array([5,10,15])

print(a+b)
# Out:
# [15 30 45]
# [ 5 10 15]
# [ 50 200 450]
# [2. 2. 2.]

# %%
marks = np.array([80,90,85,95])

print(np.sum(marks))
print(np.mean(marks))
print(np.max(marks))
print(np.min(marks))
# Out:
# 350
# 87.5
# 95
# 80

# %%
print(arr.shape)
print(arr.size)
print(arr.dtype)
# Out:
# (5,)
# 5
# int64
