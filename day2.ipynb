# %%
student_name = "Sathish Kumar S"
college_name = "Your College Name"
course = "B.Sc Artificial Intelligence and Data Science"
year = "3rd Year"

print("Student Name:", student_name)
print("College Name:", college_name)
print("Course:", course)
print("Year:", year)
# Out:
# Student Name: Sathish Kumar S
# College Name: Your College Name
# Course: B.Sc Artificial Intelligence and Data Science
# Year: 3rd Year

# %%
name = "Sathish"      
age = 20              
cgpa = 8.5            
is_student = True     

print("Name:", name)
print("Age:", age)
print("CGPA:", cgpa)
print("Student:", is_student)

print(type(name))
print(type(age))
print(type(cgpa))
print(type(is_student))
# Out:
# Name: Sathish
# Age: 20
# CGPA: 8.5
# Student: True
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
a = 20
b = 30
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor Division:", a // b)
print("Modulus:", a % b)
print("Exponent:", a ** b)
# Out:
# Addition: 50
# Subtraction: -10
# Multiplication: 600
# Division: 0.6666666666666666
# Floor Division: 0
# Modulus: 20
# Exponent: 1073741824000000000000000000000000000000
